# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

M=100000              # Total number of throws
N=100                 # Number of blocks

L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

data_integ = np.loadtxt("integrale.dat")

integrale = data_integ[:,0]
errore_integ = data_integ[:,1]

x*=L # Number of throws = block * (Number of throws in each block)
plt.errorbar(x,integrale-1,yerr=errore_integ)
plt.xlabel('#throws')
plt.ylabel('<r>-1')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

M=100000              # Total number of throws
N=100                 # Number of blocks

L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

data_integ = np.loadtxt("integraleIS.dat")

integrale = data_integ[:,0]
errore_integ = data_integ[:,1]

x*=L # Number of throws = block * (Number of throws in each block)
plt.errorbar(x,integrale-1,yerr=errore_integ)
plt.xlabel('#throws')
plt.ylabel('<r>-1')
plt.grid(True)
plt.show()
